# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha1723/AI_Projects/blob/main/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+4
# Out:
# 6

# %% [markdown]
# **Python for AI**

# %%
print('Hello AI')
# Out:
# Hello AI

# %%
'Hello AI'
# Out:
# 'Hello AI'

# %%
name = "Akanksha"
print("hello",name)
# Out:
# hello Akanksha

# %%
name = input("Enter your name")
print("Good Morning", name)
# Out:
# Enter your nameKD
# Good Morning KD

# %%
age = int(input("Enter your age"))
print(age)
# Out:
# Enter your age21
# 21

# %%
age = int(input("Enter your age:"))
print("Age:",age-5)
# Out:
# Enter your age:21
# Age: 16

# %% [markdown]
# ## **Dataset uploading**

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/AI_Survey_VAC.xlsx")

# %%
df
# Out:
#                   Timestamp              Name   Age   Daily Mobile Usage   \
# 0   2026-06-17 21:00:33.625   Dr. Divya Mishra    29                    4
# 1   2026-06-18 12:18:01.826       Vansh Tomer     20                    8
# 2   2026-06-18 12:18:04.614    Lavish chauhan     23                    1
# 3   2026-06-18 12:18:04.829   Utkarsh Chaubey     22                    5
# 4   2026-06-18 12:18:07.873   Harshit Upadhyay    21                    2
# ..                      ...                ...   ...                  ...
# 138 2026-06-18 12:21:37.766      Tushar  kumar    22                    3
# 139 2026-06-18 12:21:50.169  Govind Kumar Jha     20                    2
# 140 2026-06-18 12:21:57.362               manu    23                    8
# 141 2026-06-18 12:21:58.449         Shambhavi     22                    1
# 142 2026-06-18 12:22:21.994        Vikas kumar    22                    2
#
#      Study Hours
# 0               4
# 1               1
# 2               3
# ...

# %% [markdown]
# # **Check & Count the missing value in each column**

# %%
print(df.isnull().sum());
# Out:
# Timestamp              0
# Name                   0
# Age                    0
# Daily Mobile Usage     0
# Study Hours            0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Name , Age , Daily Mobile Usage , Study Hours ]
# Index: []

# %%
df.head(5)
# Out:
#                 Timestamp             Name   Age   Daily Mobile Usage   \
# 0 2026-06-17 21:00:33.625  Dr. Divya Mishra    29                    4
# 1 2026-06-18 12:18:01.826      Vansh Tomer     20                    8
# 2 2026-06-18 12:18:04.614   Lavish chauhan     23                    1
# 3 2026-06-18 12:18:04.829  Utkarsh Chaubey     22                    5
# 4 2026-06-18 12:18:07.873  Harshit Upadhyay    21                    2
#
#    Study Hours
# 0             4
# 1             1
# 2             3
# 3             6
# 4             4

# %%
df.tail(6)
# Out:
#                   Timestamp              Name   Age   Daily Mobile Usage   \
# 137 2026-06-18 12:21:34.437  paridhi chaudhary    23                    5
# 138 2026-06-18 12:21:37.766      Tushar  kumar    22                    3
# 139 2026-06-18 12:21:50.169  Govind Kumar Jha     20                    2
# 140 2026-06-18 12:21:57.362               manu    23                    8
# 141 2026-06-18 12:21:58.449         Shambhavi     22                    1
# 142 2026-06-18 12:22:21.994        Vikas kumar    22                    2
#
#      Study Hours
# 137             5
# 138             1
# 139             4
# 140             1
# 141             4
# 142             4

# %%
df.shape
# Out:
# (143, 5)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Name ', 'Age ', 'Daily Mobile Usage ', 'Study Hours '], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            143 non-null    datetime64[ns]
#  1   Name                 143 non-null    object
#  2   Age                  143 non-null    int64
#  3   Daily Mobile Usage   143 non-null    int64
#  4   Study Hours          143 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 5.7+ KB

# %%
df.describe()
# Out:
#                            Timestamp        Age   Daily Mobile Usage   \
# count                            143  143.000000           143.000000
# mean      2026-06-18 12:12:46.300832   22.216783             4.377622
# min       2026-06-17 21:00:33.625000   19.000000             1.000000
# 25%       2026-06-18 12:18:37.920000   21.000000             3.000000
# 50%    2026-06-18 12:18:57.870000128   22.000000             4.000000
# 75%    2026-06-18 12:19:31.198499840   23.000000             6.000000
# max       2026-06-18 12:22:21.994000   29.000000             8.000000
# std                              NaN    1.678949             2.318949
#
#        Study Hours
# count    143.000000
# mean       4.279720
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max       12.000000
# std        2.715126
