# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha1723/AI_Projects/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.6 MB/s eta 0:00:00

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Sample video for demonstration
video_url = "https://www.w3schools.com/html/mov_bbb.mp4"
video_path = "mov_bbb.mp4"

# %%
if os.path.exists(video_path):
  print(f"Removing existing file: {video_path}")
  os.remove(video_path)
print(f"Downloading sample video from {video_url}...")
# !wget-O {video_path} {video_url}
# Out:
# Downloading sample video from https://www.w3schools.com/html/mov_bbb.mp4...
# /bin/bash: line 1: wget-O: command not found

# %%
if os.path.exists(video_path):
  size_kb = os.path.getsize(video_path) / 1024
  print(f"Download complete. File size: {size_kb:.1f} KB")
  if size_kb < 10:
    print("WARNING: File is very small, it may not be a valid video (check for an HTML error page).")
else:
  print("ERROR: Download failed, file was not created.")
# Out:
# Download complete. File size: 770.0 KB

# %%
# Load a pre-trained YOLOv8n model (nano version for speed)
model = YOLO('yolov8n.pt')
print("YOLOv8n model loaded successfully.")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 67.9MB/s 0.1s
# YOLOv8n model loaded successfully.

# %%
input_video_path = video_path
output_video_path = "output_detection_video.mp4"
# Open the video file
cap = cv2.VideoCapture(input_video_path)

# %%
if not cap.isOpened():
  print(f"Error: Could not open video file {input_video_path}. Please check the file path or if it's corrupted.")
else:
  # Get video properties
  fps = int(cap.get(cv2.CAP_PROP_FPS))
  width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
  height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
  print(f"Original Video Properties: FPS={fps}, Width={width}, Height={height}")
# Out:
# Original Video Properties: FPS=25, Width=320, Height=176

# %%
if fps <= 0:
  print("Warning: FPS is 0 or less. Setting to default 24 FPS.")
  fps = 24
if width <= 0:
  print("Warning: Width is 0 or less. Setting to default 1280 pixels.")
  width = 1280
if height <= 0:
  print("Warning: Height is 0 or less. Setting to default 720 pixels.")
  height = 720

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for .mp4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
if not out.isOpened():
  print(f"Error: Could not open video writer for {output_video_path}. Check codec or file permissions.")
else:
  frame_count = 0
  MAX_FRAMES_TO_PROCESS = 300
  print(f"Processing video: {input_video_path}. Saving output to: {output_video_path}")
  print(f"This might take a while, processing up to {MAX_FRAMES_TO_PROCESS} frames.")
# Out:
# Processing video: mov_bbb.mp4. Saving output to: output_detection_video.mp4
# This might take a while, processing up to 300 frames.

# %%
while cap.isOpened() and frame_count < MAX_FRAMES_TO_PROCESS:
  ret, frame = cap.read()
  if not ret:
    print(f"End of video or failed to read frame at frame_count {frame_count}.")
    break
  results = model(frame)
  # Draw bounding boxes and labels on the frame
  annotated_frame = results[0].plot()
# Out:
# 0: 352x640 1 dog, 1 kite, 265.8ms
# Speed: 16.0ms preprocess, 265.8ms inference, 30.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 kite, 115.2ms
# Speed: 2.0ms preprocess, 115.2ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 kite, 127.2ms
# Speed: 2.4ms preprocess, 127.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 116.1ms
# Speed: 3.2ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 118.5ms
# Speed: 2.0ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 116.5ms
# Speed: 2.7ms preprocess, 116.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 110.5ms
# Speed: 2.4ms preprocess, 110.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.8ms
# Speed: 2.9ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 111.7ms
# Speed: 3.5ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 125.4ms
# Speed: 2.0ms preprocess, 125.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.2ms
# Speed: 2.1ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 113.5ms
# Speed: 2.2ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 116.1ms
# Speed: 2.5ms preprocess, 116.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 123.6ms
# Speed: 2.4ms preprocess, 123.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 111.4ms
# Speed: 3.1ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 115.4ms
# Speed: 2.4ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 119.5ms
# Speed: 2.9ms preprocess, 119.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 131.1ms
# Speed: 2.4ms preprocess, 131.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 116.7ms
# Speed: 3.4ms preprocess, 116.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 kite, 120.6ms
# Speed: 2.8ms preprocess, 120.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 kite, 111.8ms
# Speed: 2.8ms preprocess, 111.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 115.8ms
# Speed: 3.7ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 115.4ms
# Speed: 2.3ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 cat, 1 sheep, 116.1ms
# Speed: 4.0ms preprocess, 116.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 111.5ms
# Speed: 2.5ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 122.3ms
# Speed: 2.4ms preprocess, 122.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 112.8ms
# Speed: 2.8ms preprocess, 112.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 116.1ms
# Speed: 3.5ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.1ms
# Speed: 2.5ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 dogs, 109.6ms
# Speed: 3.0ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 115.9ms
# Speed: 3.1ms preprocess, 115.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 113.4ms
# Speed: 2.7ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 113.4ms
# Speed: 3.1ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 114.5ms
# Speed: 2.5ms preprocess, 114.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 dogs, 127.5ms
# Speed: 3.5ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 111.4ms
# Speed: 3.1ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 1 kite, 114.5ms
# Speed: 2.9ms preprocess, 114.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 113.7ms
# Speed: 2.7ms preprocess, 113.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 119.1ms
# Speed: 2.7ms preprocess, 119.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 kite, 117.7ms
# Speed: 3.9ms preprocess, 117.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 112.8ms
# Speed: 2.1ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 1 dog, 116.3ms
# Speed: 2.5ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 126.2ms
# Speed: 1.8ms preprocess, 126.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 1 dog, 111.3ms
# Speed: 3.2ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 1 dog, 137.3ms
# Speed: 3.5ms preprocess, 137.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 178.7ms
# Speed: 3.3ms preprocess, 178.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 176.3ms
# Speed: 3.6ms preprocess, 176.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 frisbee, 179.2ms
# Speed: 4.0ms preprocess, 179.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 185.2ms
# Speed: 5.3ms preprocess, 185.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 182.4ms
# Speed: 4.9ms preprocess, 182.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 179.3ms
# Speed: 4.5ms preprocess, 179.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 173.5ms
# Speed: 3.9ms preprocess, 173.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 172.6ms
# Speed: 3.2ms preprocess, 172.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 168.8ms
# Speed: 2.9ms preprocess, 168.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 cat, 182.2ms
# Speed: 3.0ms preprocess, 182.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 cat, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 cat, 183.0ms
# Speed: 4.0ms preprocess, 183.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 cat, 168.7ms
# Speed: 2.3ms preprocess, 168.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 184.2ms
# Speed: 3.9ms preprocess, 184.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 184.3ms
# Speed: 3.2ms preprocess, 184.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 132.8ms
# Speed: 4.5ms preprocess, 132.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 113.6ms
# Speed: 2.5ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 113.2ms
# Speed: 2.3ms preprocess, 113.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 113.4ms
# Speed: 2.3ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 113.0ms
# Speed: 2.1ms preprocess, 113.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 112.0ms
# Speed: 2.1ms preprocess, 112.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 112.9ms
# Speed: 2.1ms preprocess, 112.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 frisbee, 116.8ms
# Speed: 3.4ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 frisbee, 123.8ms
# Speed: 3.3ms preprocess, 123.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 113.6ms
# Speed: 2.4ms preprocess, 113.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 113.1ms
# Speed: 2.5ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.0ms
# Speed: 2.4ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.6ms
# Speed: 2.8ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 114.6ms
# Speed: 2.6ms preprocess, 114.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 119.7ms
# Speed: 5.6ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 111.7ms
# Speed: 2.9ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 203.6ms
# Speed: 3.5ms preprocess, 203.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 112.7ms
# Speed: 2.6ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 1 dog, 115.9ms
# Speed: 3.4ms preprocess, 115.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 dogs, 115.9ms
# Speed: 2.2ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 113.9ms
# Speed: 3.2ms preprocess, 113.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 114.7ms
# Speed: 2.6ms preprocess, 114.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 114.7ms
# Speed: 3.5ms preprocess, 114.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 119.5ms
# Speed: 3.0ms preprocess, 119.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 dog, 127.4ms
# Speed: 3.3ms preprocess, 127.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 115.1ms
# Speed: 2.5ms preprocess, 115.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 110.8ms
# Speed: 2.6ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 dogs, 115.2ms
# Speed: 2.4ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 dogs, 121.0ms
# Speed: 2.7ms preprocess, 121.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 115.4ms
# Speed: 3.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 bear, 115.1ms
# Speed: 3.2ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 bear, 114.9ms
# Speed: 2.8ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 127.4ms
# Speed: 3.1ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 115.2ms
# Speed: 2.7ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 sheeps, 1 cow, 1 kite, 113.5ms
# Speed: 2.9ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 kite, 115.2ms
# Speed: 2.3ms preprocess, 115.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 sheeps, 1 kite, 113.1ms
# Speed: 2.2ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 kite, 110.7ms
# Speed: 2.4ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 1 kite, 115.6ms
# Speed: 3.5ms preprocess, 115.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 1 kite, 120.1ms
# Speed: 1.9ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 cow, 1 kite, 124.0ms
# Speed: 3.0ms preprocess, 124.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 kite, 116.7ms
# Speed: 2.6ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 kite, 115.7ms
# Speed: 2.7ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 kite, 111.8ms
# Speed: 2.8ms preprocess, 111.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 110.7ms
# Speed: 2.7ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 cow, 1 kite, 112.4ms
# Speed: 3.0ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 cow, 118.2ms
# Speed: 2.7ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 cow, 115.6ms
# Speed: 2.6ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 128.6ms
# Speed: 2.5ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 sheeps, 1 cow, 115.1ms
# Speed: 1.8ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 119.2ms
# Speed: 1.9ms preprocess, 119.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 115.8ms
# Speed: 2.9ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 114.7ms
# Speed: 3.5ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 113.8ms
# Speed: 2.6ms preprocess, 113.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 118.3ms
# Speed: 3.7ms preprocess, 118.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 116.9ms
# Speed: 3.4ms preprocess, 116.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 127.2ms
# Speed: 2.3ms preprocess, 127.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 2 sheeps, 112.8ms
# Speed: 3.0ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 111.7ms
# Speed: 2.8ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 113.4ms
# Speed: 2.7ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 113.5ms
# Speed: 3.2ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 112.0ms
# Speed: 2.4ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 111.9ms
# Speed: 2.3ms preprocess, 111.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 111.3ms
# Speed: 2.9ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 111.5ms
# Speed: 2.5ms preprocess, 111.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 135.8ms
# Speed: 2.7ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 112.6ms
# Speed: 2.6ms preprocess, 112.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 112.7ms
# Speed: 3.8ms preprocess, 112.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 109.2ms
# Speed: 3.3ms preprocess, 109.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 110.3ms
# Speed: 3.0ms preprocess, 110.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 117.0ms
# Speed: 2.3ms preprocess, 117.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 115.8ms
# Speed: 3.0ms preprocess, 115.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 117.6ms
# Speed: 3.9ms preprocess, 117.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sheep, 130.2ms
# Speed: 3.5ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 122.9ms
# Speed: 3.4ms preprocess, 122.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 113.9ms
# Speed: 2.7ms preprocess, 113.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 113.7ms
# Speed: 3.4ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 113.6ms
# Speed: 2.6ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 121.2ms
# Speed: 2.9ms preprocess, 121.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 189.5ms
# Speed: 4.0ms preprocess, 189.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sheep, 187.1ms
# Speed: 2.4ms preprocess, 187.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 178.5ms
# Speed: 2.5ms preprocess, 178.5ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 176.7ms
# Speed: 3.2ms preprocess, 176.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 181.1ms
# Speed: 2.3ms preprocess, 181.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 190.1ms
# Speed: 2.8ms preprocess, 190.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 172.2ms
# Speed: 2.3ms preprocess, 172.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 180.2ms
# Speed: 4.3ms preprocess, 180.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 166.7ms
# Speed: 2.4ms preprocess, 166.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 165.3ms
# Speed: 2.2ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 182.2ms
# Speed: 2.5ms preprocess, 182.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 175.4ms
# Speed: 3.1ms preprocess, 175.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 180.1ms
# Speed: 3.9ms preprocess, 180.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 183.6ms
# Speed: 3.3ms preprocess, 183.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 181.9ms
# Speed: 2.7ms preprocess, 181.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 177.4ms
# Speed: 4.4ms preprocess, 177.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 110.9ms
# Speed: 3.3ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 117.3ms
# Speed: 3.5ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 114.9ms
# Speed: 2.5ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 115.8ms
# Speed: 2.4ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 128.4ms
# Speed: 2.4ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 114.3ms
# Speed: 3.1ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 111.7ms
# Speed: 2.4ms preprocess, 111.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 119.5ms
# Speed: 2.9ms preprocess, 119.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 114.3ms
# Speed: 2.9ms preprocess, 114.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 birds, 112.9ms
# Speed: 3.4ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 giraffe, 113.2ms
# Speed: 2.6ms preprocess, 113.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 115.4ms
# Speed: 2.5ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 136.0ms
# Speed: 2.6ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 114.6ms
# Speed: 2.9ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 117.4ms
# Speed: 2.6ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 121.9ms
# Speed: 2.5ms preprocess, 121.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 birds, 1 teddy bear, 116.7ms
# Speed: 2.6ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 birds, 117.7ms
# Speed: 2.5ms preprocess, 117.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 114.8ms
# Speed: 2.8ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 birds, 115.0ms
# Speed: 2.7ms preprocess, 115.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 128.6ms
# Speed: 2.7ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 111.4ms
# Speed: 2.5ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 114.4ms
# Speed: 3.4ms preprocess, 114.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 116.8ms
# Speed: 2.5ms preprocess, 116.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 114.3ms
# Speed: 3.7ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 bird, 115.7ms
# Speed: 2.3ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 bird, 1 kite, 112.2ms
# Speed: 3.2ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 128.3ms
# Speed: 3.7ms preprocess, 128.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 117.4ms
# Speed: 2.9ms preprocess, 117.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 114.8ms
# Speed: 2.8ms preprocess, 114.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sports ball, 117.6ms
# Speed: 2.7ms preprocess, 117.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sports ball, 1 teddy bear, 114.1ms
# Speed: 2.6ms preprocess, 114.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sports ball, 115.9ms
# Speed: 2.5ms preprocess, 115.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sports ball, 115.3ms
# Speed: 2.5ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 114.7ms
# Speed: 2.5ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 116.3ms
# Speed: 2.6ms preprocess, 116.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 sports ball, 120.5ms
# Speed: 2.4ms preprocess, 120.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sports ball, 120.5ms
# Speed: 3.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 118.4ms
# Speed: 3.1ms preprocess, 118.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sports ball, 112.4ms
# Speed: 2.6ms preprocess, 112.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 114.4ms
# Speed: 2.1ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sports ball, 116.1ms
# Speed: 2.6ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 dog, 1 sports ball, 115.0ms
# Speed: 3.1ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 1 sports ball, 112.0ms
# Speed: 3.3ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 1 sports ball, 133.9ms
# Speed: 3.9ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 115.0ms
# Speed: 2.7ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sheep, 1 sports ball, 116.3ms
# Speed: 3.4ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 110.4ms
# Speed: 3.8ms preprocess, 110.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 114.1ms
# Speed: 2.7ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 113.0ms
# Speed: 4.9ms preprocess, 113.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 110.5ms
# Speed: 2.5ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 111.2ms
# Speed: 3.6ms preprocess, 111.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 123.5ms
# Speed: 2.7ms preprocess, 123.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 116.3ms
# Speed: 2.5ms preprocess, 116.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 117.7ms
# Speed: 2.8ms preprocess, 117.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 126.2ms
# Speed: 2.7ms preprocess, 126.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 114.5ms
# Speed: 3.2ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 278.7ms
# Speed: 3.7ms preprocess, 278.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 120.6ms
# Speed: 4.4ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 128.7ms
# Speed: 2.4ms preprocess, 128.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 121.5ms
# Speed: 3.0ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 118.5ms
# Speed: 3.1ms preprocess, 118.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 119.8ms
# Speed: 2.5ms preprocess, 119.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 114.4ms
# Speed: 1.9ms preprocess, 114.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 126.9ms
# Speed: 2.8ms preprocess, 126.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 110.4ms
# Speed: 2.5ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 115.2ms
# Speed: 3.1ms preprocess, 115.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 125.0ms
# Speed: 3.5ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 116.4ms
# Speed: 2.9ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 111.3ms
# Speed: 2.1ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 119.8ms
# Speed: 2.6ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 113.1ms
# Speed: 3.3ms preprocess, 113.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 109.9ms
# Speed: 3.1ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 110.7ms
# Speed: 2.8ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 1 sports ball, 111.5ms
# Speed: 2.4ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sports ball, 131.2ms
# Speed: 2.8ms preprocess, 131.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bird, 1 sheep, 1 sports ball, 193.8ms
# Speed: 2.6ms preprocess, 193.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 1 sports ball, 171.9ms
# Speed: 2.5ms preprocess, 171.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 sheep, 1 sports ball, 174.1ms
# Speed: 2.5ms preprocess, 174.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 sports ball, 179.8ms
# Speed: 2.7ms preprocess, 179.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 177.9ms
# Speed: 4.2ms preprocess, 177.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 195.7ms
# Speed: 3.5ms preprocess, 195.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 sports ball, 182.8ms
# Speed: 4.0ms preprocess, 182.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 sports ball, 173.1ms
# Speed: 4.2ms preprocess, 173.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 1 sports ball, 174.0ms
# Speed: 3.5ms preprocess, 174.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 dog, 2 sheeps, 172.3ms
# Speed: 3.7ms preprocess, 172.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 251.1ms
# Speed: 4.1ms preprocess, 251.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 288.1ms
# Speed: 5.1ms preprocess, 288.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 176.7ms
# Speed: 3.2ms preprocess, 176.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 177.4ms
# Speed: 2.3ms preprocess, 177.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 186.5ms
# Speed: 2.4ms preprocess, 186.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 1 sports ball, 172.5ms
# Speed: 3.1ms preprocess, 172.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 sheeps, 116.0ms
# Speed: 2.8ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# End of video or failed to read frame at frame_count 0.

# %%
if annotated_frame.shape[1] != width or annotated_frame.shape[0] != height:
  annotated_frame = cv2.resize(annotated_frame, (width, height))
  out.write(annotated_frame)
  frame_count += 1
  if frame_count % 50 == 0:
    print(f"Processed {frame_count} frames...")
  cap.release()
  out.release()
  print(f"Video processing complete. Output saved to {output_video_path}")

# %%
display_frames = 5 # Number of frames to display
displayed_count = 0
cap_output = cv2.VideoCapture(output_video_path)

# %%
while cap_output.isOpened() and displayed_count < display_frames:
  ret, frame = cap_output.read()
  if not ret:
    break
  print(f"Frame {displayed_count + 1} from output video:")
  cv2_imshow(frame)
  displayed_count += 1
cap_output.release()
print(f"\nYou can also download the full processed video from: {output_video_path}")
# Out:
# You can also download the full processed video from: output_detection_video.mp4
