# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha1723/AI_Projects/blob/main/Module2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # **Load the dataset**

# %%
df = pd.read_csv("/content/AI_Survey_VAC.csv")

# %%
df
# Out:
#               Timestamp              Name   Age   Daily Mobile Usage   \
# 0    6/17/2026 21:00:34   Dr. Divya Mishra  29.0                  4.0
# 1    6/18/2026 12:18:02       Vansh Tomer   20.0                  8.0
# 2    6/18/2026 12:18:05    Lavish chauhan   23.0                  1.0
# 3    6/18/2026 12:18:05   Utkarsh Chaubey   22.0                  5.0
# 4    6/18/2026 12:18:08   Harshit Upadhyay  21.0                  2.0
# ..                  ...                ...   ...                  ...
# 139  6/18/2026 12:21:50  Govind Kumar Jha   20.0                  2.0
# 140  6/18/2026 12:21:57      Chirag Sharma  22.0                  8.0
# 141  6/18/2026 12:21:58         Shambhavi   22.0                  1.0
# 142  6/18/2026 12:22:22        Vikas kumar  22.0                  2.0
# 143  6/18/2026 12:22:36     Tatya Bichhoo   29.0                  8.0
#
#      Study Hours
# 0             4.0
# 1             1.0
# 2             3.0
# 3             6.0
# 4             4.0
# ...

# %% [markdown]
# ### **Display basic information**

# %%
df.shape
# Out:
# (144, 5)

# %%
df.head()
# Out:
#             Timestamp             Name   Age   Daily Mobile Usage   \
# 0  6/17/2026 21:00:34  Dr. Divya Mishra    29                    4
# 1  6/18/2026 12:18:02      Vansh Tomer     20                    8
# 2  6/18/2026 12:18:05   Lavish chauhan     23                    1
# 3  6/18/2026 12:18:05  Utkarsh Chaubey     22                    5
# 4  6/18/2026 12:18:08  Harshit Upadhyay    21                    2
#
#    Study Hours
# 0             4
# 1             1
# 2             3
# 3             6
# 4             4

# %%
df.tail()
# Out:
#               Timestamp              Name   Age   Daily Mobile Usage   \
# 139  6/18/2026 12:21:50  Govind Kumar Jha     20                    2
# 140  6/18/2026 12:21:57               manu    23                    8
# 141  6/18/2026 12:21:58         Shambhavi     22                    1
# 142  6/18/2026 12:22:22        Vikas kumar    22                    2
# 143  6/18/2026 12:22:36     Tatya Bichhoo     29                    8
#
#      Study Hours
# 139             4
# 140             1
# 141             4
# 142             4
# 143             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            144 non-null    object
#  1   Name                 144 non-null    object
#  2   Age                  144 non-null    int64
#  3   Daily Mobile Usage   144 non-null    int64
#  4   Study Hours          144 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 5.8+ KB

# %%
df.describe()
# Out:
#              Age   Daily Mobile Usage   Study Hours
# count  144.000000           144.000000    144.000000
# mean    22.263889             4.402778      4.256944
# std      1.765980             2.330459      2.719385
# min     19.000000             1.000000      1.000000
# 25%     21.000000             3.000000      2.750000
# 50%     22.000000             4.000000      4.000000
# 75%     23.000000             6.000000      5.000000
# max     29.000000             8.000000     12.000000

# %% [markdown]
# ### **Check for missing values**

# %%
print(df.isnull().sum());
# Out:
# Timestamp              0
# Name                   0
# Age                    0
# Daily Mobile Usage     0
# Study Hours            0
# dtype: int64

# %% [markdown]
# ### **Check for duplicate rows**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.columns = df.columns.str.strip()

# %%
df['Age'] = df['Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_2242/4210971486.py in <cell line: 0>()
# ----> 1 df['Age'] = df['Age'].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %% [markdown]
# ## **Statistical Analysis**

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].mean())
# Out:
# Age                   22.274648
# Daily Mobile Usage     4.408451
# Study Hours            4.244755
# dtype: float64

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].median())
# Out:
# Age                   22.0
# Daily Mobile Usage     4.0
# Study Hours            4.0
# dtype: float64

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].mode().iloc[0])
# Out:
# Age                   22.0
# Daily Mobile Usage     8.0
# Study Hours            4.0
# Name: 0, dtype: float64

# %% [markdown]
# ## **Correlation Analysis**

# %%
correlation = df[['Age','Daily Mobile Usage','Study Hours']].corr()

# %%
print(correlation)
# Out:
#                          Age  Daily Mobile Usage  Study Hours
# Age                 1.000000            0.243879     0.258836
# Daily Mobile Usage  0.243879            1.000000     0.125926
# Study Hours         0.258836            0.125926     1.000000

# %% [markdown]
# # **Create categories for mobile usage**

# %%
df['Mobile Usage Category'] = pd.cut(
   df['Daily Mobile Usage'],
   bins = [0,2,4,6,8,12],
   labels = ['Very Low','Low','Medium','High','Very High']
)

# %%
print(df['Mobile Usage Category'].value_counts())
# Out:
# Mobile Usage Category
# Low          47
# Very Low     34
# High         34
# Medium       27
# Very High     0
# Name: count, dtype: int64

# %% [markdown]
# ## **Set style for better visualizations**

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8-darkgrid')

# %%
sns.set_palette("husl")

# %% [markdown]
# # **Create a figure with subplots**

# %%
fig = plt.figure(figsize = (18,12))

# %% [markdown]
# ## **Distribution of Age**

# %%
plt.subplot(2,3,1)
# Out:
# <Axes: >

# %%
sns.histplot(df_clean['Age'],bins=15,kde=True)
plt.title('Distribution of ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2242/1764285650.py in <cell line: 0>()
# ----> 1 sns.histplot(df_clean['Age'],bins=15,kde=True)
#
# NameError: name 'df_clean' is not defined

# %%
plt.title('Distribution of ')

# %%
df = pd.read_excel("/content/AI_Survey_VAC1.csv.xlsx")

# %%
df
# Out:
#               Timestamp              Name   Age   Daily Mobile Usage   \
# 0    6/17/2026 21:00:34   Dr. Divya Mishra  29.0                  4.0
# 1    6/18/2026 12:18:02       Vansh Tomer   20.0                  8.0
# 2    6/18/2026 12:18:05    Lavish chauhan   23.0                  1.0
# 3    6/18/2026 12:18:05   Utkarsh Chaubey   22.0                  5.0
# 4    6/18/2026 12:18:08   Harshit Upadhyay  21.0                  2.0
# ..                  ...                ...   ...                  ...
# 139  6/18/2026 12:21:50  Govind Kumar Jha   20.0                  2.0
# 140  6/18/2026 12:21:57      Chirag Sharma  22.0                  NaN
# 141  6/18/2026 12:21:58         Shambhavi   22.0                  1.0
# 142  6/18/2026 12:22:22        Vikas kumar  22.0                  2.0
# 143  6/18/2026 12:22:36     Tatya Bichhoo   29.0                  8.0
#
#      Study Hours
# 0             4.0
# 1             1.0
# 2             3.0
# 3             6.0
# 4             4.0
# ...

# %%
print(df.isnull().sum())
# Out:
# Timestamp              0
# Name                   0
# Age                    2
# Daily Mobile Usage     4
# Study Hours            1
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## **Clean Column names (Remove space)**

# %%
df.columns = df.columns.str.strip()

# %% [markdown]
# # **Check data types**

# %%
df.dtypes
# Out:
# Timestamp              object
# Name                   object
# Age                   float64
# Daily Mobile Usage    float64
# Study Hours           float64
# dtype: object

# %% [markdown]
# ## **Convert age to integer (if needed)**

# %%
df['Age'] = df['Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_2242/4210971486.py in <cell line: 0>()
# ----> 1 df['Age'] = df['Age'].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
print("\nMean values:")
# Out:
# Mean values:

# %%
print(df[['Age','Daily Mobile Usage','Study Hours']].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2242/1854827101.py in <cell line: 0>()
# ----> 1 print(df[['Age','Daily Mobile Usage','Study Hours']].mean())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
